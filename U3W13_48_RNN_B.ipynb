# %% [markdown]
# <a href="https://colab.research.google.com/github/Akashkumar12/AI-ML/blob/main/U3W13_48_RNN_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint

# %% [markdown]
# ### Learning Objectives

# %% [markdown]
# At the end of the experiment, you will be able to:
#
# 1.   Generate text which is similar to the writing style of William Shakespeare
# 2.   Understand how to adapt or tune the trained network

# %%
#@title Experiment Explanation Video
from IPython.display import HTML

HTML("""<video width="800" height="300" controls>
  <source src="https://cdn.talentsprint.com/talentsprint/archives/sc/aiml/module_3_week_12_experiment_1.mp4" type="video/mp4">
</video>
""")

# %% [markdown]
# ### Dataset

# %% [markdown]
# ####  Description
#
# The dataset used in this experiment has partial content of different plays of Shakespeare concatenated into a single plain text file.
#
# Shakespeare is a famous English poet , play writer and actor. He is regarded as the greatest writer in the English language and the world's greatest dramatist. He is often called a England's national poet and the Bard of Avon.
#
# We have chosen plays of Shakespeare as our dataset mainly for two reasons :
#
# 1. His work is widely recognized as standard for poetry and language.
# 2. The result of combining of his work provides a sizeable corpus for our model to learn.
#
# The plays of Shakespeare are taken from the following url:
#
# www.opensourceshakespeare.org/views/plays/plays.php

# %% [markdown]
# ### Domain Information

# %% [markdown]
# Music and Art are considered creative in nature and creating them is assumed to be more difficult when compared to writing a book, article or text. But the reality is that creating music and art is less complicated because there are no strict rules like which direction should one paint in or when to pause between the notes. However,  while writing a text one must follow grammatical rules. Hence, writing/generating text task is more related to machine learning and artificial intelligence.

# %% [markdown]
# ### AI/ML Technique

# %% [markdown]
# The RNN algorithm is used to generate text which is similar to the writing style of Shakespeare. Let us try to understand the main idea behind using this algorithm.
#
# #### RNN algorithm
#
# The main idea is to use sequential information. In a traditional neural network we assume that all inputs (and outputs) are independent of each other. But for many tasks that’s a bad idea. If you want to predict the next word in a sentence you better know which words came before it. This is possible through RNN. RNNs are called recurrent because they perform the same task for every element of a sequence, with the output being depended on the previous computations.
#
# *Example:*  Take an example string **“HELLO”**. The vocabulary of the example is made of four letters or characters H,E,L,O. Now, let us apply RNN algorithm on this.
#
# Give *'H'* as input to the trained RNN model, it would give us an output *'E'*. In the next stage, this output *'E'* is passed as the new input which would give us the new output *'L'*. As the cycle follows, this output *'L'* is the new input but then what do you think the new output should be, second *‘L’* or *‘O’*? This is the challenge in predicting the next letter or character which RNN can solve. RNN has its own memory which helps it to predict based on the previous characters in this case H, E and L. Hence the output would most probably be *'L'* and not *'O'*.

# %% [markdown]
# ![alt text](https://cdn.talentsprint.com/aiml/Experiment_related_data/IMAGES/7.1.png)

# %% [markdown]
# In this experiment we will follow below steps:
#
# 1.   Preparing the data
# 2.   Building the model
# 3.   Defining helper functions
# 4.   Training the model
# 5.    Adapting or Fine-tuning for text generation

# %% [markdown]
# ### Setup Steps:

# %%
#@title Please enter your registration id to start: { run: "auto", display-mode: "form" }
Id = "2514879" #@param {type:"string"}

# %%
#@title Please enter your password (normally your phone number) to continue: { run: "auto", display-mode: "form" }
password = "9545114527" #@param {type:"string"}

# %% [markdown]
# ##### After creating a copy of the notebook, follow the instructions below based on your batch:
#
# * PG Batch: Run the below cell as it is.
#
# * AC (Advanced) Batch: Follow the steps below to avoid execution errors.
#
# 1. Click on “Show Code” under the cell labeled:
#     “Run this cell to complete the setup for this Notebook.”
#
# 2. Refer to the attached snippet and locate the red-highlighted section.
#
# 4. Add the following code snippet under the “Show Code” section, ensuring that the correct cohort ID is used in place of the example shown below:
#
#            "batch": "IIITH-AC-AIML-27"
#
# ![Colab Error.png](data:image/png;base64,...)

# %%
#@title Run this cell to complete the setup for this Notebook
from IPython import get_ipython

ipython = get_ipython()

notebook= "U3W13_48_RNN_B" #name of the notebook

def setup():
#  ipython.magic("sx pip3 install torch")
    from IPython.display import HTML, display
    ipython.magic("sx pip3 install torch")
    ipython.magic("sx pip3 install Unidecode")
    ipython.magic("sx pip3 install unidecode")
    ipython.magic("sx wget https://cdn.talentsprint.com/aiml/Experiment_related_data/week10/Exp1/shakespeare.txt")
    display(HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id)))
    print("Setup completed successfully")
    return

def submit_notebook():

    ipython.magic("notebook -e "+ notebook + ".ipynb")

    import requests, json, base64, datetime

    url = "https://dashboard.talentsprint.com/xp/app/save_notebook_attempts"
    if not submission_id:
      data = {"id" : getId(), "notebook" : notebook, "mobile" : getPassword(), "batch" : "IIITH-AC-AIML-27"}
      r = requests.post(url, data = data)
      r = json.loads(r.text)

      if r["status"] == "Success":
          return r["record_id"]
      elif "err" in r:
        print(r["err"])
        return None
      else:
        print ("Something is wrong, the notebook will not be submitted for grading")
        return None

    elif getComplexity() and getAdditional() and getConcepts() and getComments():
      f = open(notebook + ".ipynb", "rb")
      file_hash = base64.b64encode(f.read())

      data = {"complexity" : Complexity, "additional" :Additional,
              "concepts" : Concepts, "record_id" : submission_id,
              "id" : Id, "file_hash" : file_hash,
              "feedback_experiments_input" : Comments, "notebook" : notebook, "batch" : "IIITH-AC-AIML-27"}

      r = requests.post(url, data = data)
      r = json.loads(r.text)
      if "err" in r:
        print(r["err"])
        return None
      else:
        print("Your submission is successful.")
        print("Ref Id:", submission_id)
        print("Date of submission: ", r["date"])
        print("Time of submission: ", r["time"])
        print("View your submissions: https://learn-iiith.talentsprint.com/notebook_submissions")
        # print("For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.")
      return submission_id
    else: submission_id


def getAdditional():
  try:
    if not Additional:
      raise NameError
    else:
      return Additional
  except NameError:
    print ("Please answer Additional Question")
    return None
def getComments():
  try:
    if not Comments:
      raise NameError
    else:
      return Comments
  except NameError:
    print ("Please answer Comments Question")
    return None

def getComplexity():
  try:
    if not Complexity:
      raise NameError
    else:
      return Complexity
  except NameError:
    print ("Please answer Complexity Question")
    return None

def getConcepts():
  try:
    if not Concepts:
      raise NameError
    else:
      return Concepts
  except NameError:
    print ("Please answer Concepts Question")
    return None

def getId():
  try:
    return Id if Id else None
  except NameError:
    return None

def getPassword():
  try:
    return password if password else None
  except NameError:
    return None

submission_id = None
### Setup
if getPassword() and getId():
  submission_id = submit_notebook()
  if submission_id:
    setup()

else:
  print ("Please complete Id and Password cells before running setup")
# Out:
# <script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId=2514879&recordId=5038"></script>
# Setup completed successfully

# %% [markdown]
# ### Importing required packages

# %%
import unidecode
import string
import random
import torch
import torch.nn as nn
from torch.autograd import Variable

import time, math

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# ### 1. Preparing the Data
#
# The file here is a plain text file. By using the [unidecode](https://pypi.org/project/Unidecode/) package turn any potential unicode characters into plain ASCII

# %%
# Code to extract all sets of punctuation, digits, ascii_letters and whitespace characters
all_characters = string.printable

# Code to find length of all_characters and storing the value in n_characters
n_characters = len(all_characters)

# Use unidecode to convert unicode characters into plain ASCII
file = unidecode.unidecode(open('shakespeare.txt').read())

# Code to find length of the file
file_len = len(file)

# Printing the length of the file
print('file_len =', file_len)
# Out:
# file_len = 1115393

# %% [markdown]
# The variable 'file' is a string with 1115393 characters. This is the raw content of the Shakespeare text file (dataset file), including many details like white spaces, line breaks etc.
#
# Now to get the sense of the data we print first 1000 characters in the string:

# %%
file[:1000]
# Out:
# "First Citizen:\nBefore we proceed any further, hear me speak.\n\nAll:\nSpeak, speak.\n\nFirst Citizen:\nYou are all resolved rather to die than to famish?\n\nAll:\nResolved. resolved.\n\nFirst Citizen:\nFirst, you know Caius Marcius is chief enemy to the people.\n\nAll:\nWe know't, we know't.\n\nFirst Citizen:\nLet us kill him, and we'll have corn at our own price.\nIs't a verdict?\n\nAll:\nNo more talking on't; let it be done: away, away!\n\nSecond Citizen:\nOne word, good citizens.\n\nFirst Citizen:\nWe are accounted poor citizens, the patricians good.\nWhat authority surfeits on would relieve us: if they\nwould yield us but the superfluity, while it were\nwholesome, we might guess they relieved us humanely;\nbut they think we are too dear: the leanness that\nafflicts us, the object of our misery, is as an\ninventory to particularise their abundance; our\nsufferance is a gain to them Let us revenge this with\nour pikes, ere we become rakes: for the gods know I\nspeak this in hunger for bread, not in thirst for revenge.\n\n"

# %% [markdown]
# As the string is large, split it into chunks to provide inputs to the RNN using the function random_chunk()

# %%
# Initialization of the chunk length for the number of RNN's in a particular length, so that it can recall up to 200 timesteps backwards.
chunk_len = 200

# Function to split the string into chunks
def random_chunk():

    # Initializing the starting index value of the big string
    start_index = random.randint(0, file_len - chunk_len)

    # Initializing the ending index of the string
    end_index = start_index + chunk_len + 1

    # Returning the chunk
    return file[start_index:end_index]

# Printing the random chunk string
print(random_chunk())
# Out:
#  confess so much, were a kind of
# ingrateful injury; to report otherwise, were a
# malice, that, giving itself the lie, would pluck
# reproof and rebuke from every ear that heard it.
#
# First Officer:
# No more

# %% [markdown]
# ###  2. Building the Model
#
# This model will take input as the character for step $t_{-1}$, and is expected to give the output $t$, which is the next character. There are three layers:
# 1. Linear layer that encodes the input character into an internal state
# 2. GRU layer (which may itself have multiple layers) that operates on that internal and hidden state.
#     - If you want to try for RNN, just replace the nn.GRU with nn.RNN. Refer to RNN link [RNN](https://pytorch.org/docs/master/generated/torch.nn.RNN.html)
# 3. Decoder layer that outputs the probability distribution

# %%
# Creating recurrent neural network
class RNN(nn.Module):

    def __init__(self, input_size, hidden_size, output_size, n_layers=1):
        super(RNN, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.encoder = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers) # If you want to use RNN you can replace GRU with RNN and see the results
        self.decoder = nn.Linear(hidden_size, output_size)

    def forward(self, input, hidden):
        input = self.encoder(input.view(1, -1))
        output, hidden = self.gru(input.view(1, 1, -1), hidden) # Change self.gru to self.rnn if you are constructing the RNN layer
        output = self.decoder(output.view(1, -1))
        return output, hidden

    def init_hidden(self):
        # Here we are Initializing the hidden layer to zero everytime
        return Variable(torch.zeros(self.n_layers, 1, self.hidden_size))

# %% [markdown]
# ### 3. Defining the Helper Functions
#
# Let us define some helper functions to:
#
# 1. Convert the input string chunks into the character tensors
# 2. Evaluate the model

# %% [markdown]
# #### Inputs and Targets
# Each chunk will be turned into a tensor, specifically a LongTensor (used for integer values), by looping through the characters of the string and looking up the index of each character in all_characters.

# %%
# Turn string into list of longs
def char_tensor(string):
    tensor = torch.zeros(len(string)).long()
    for c in range(len(string)):
        tensor[c] = all_characters.index(string[c])
    return Variable(tensor)

# Let us print the tensor value for a given sample string, you can modify the string here...
print(char_tensor('abcDEF'))
# Out:
# tensor([10, 11, 12, 39, 40, 41])

# %% [markdown]
# Finally you assemble a pair of input and target tensors for training, from a random chunk. The input will be all characters up to the end, and the target will be all characters from the first. So if our chunk is "abc" the input will correspond to "ab" while the target is "bc".

# %%
def random_training_set():
    chunk = random_chunk()
    inp = char_tensor(chunk[:-1])
    target = char_tensor(chunk[1:])
    return inp, target

# %% [markdown]
# #### Evaluating
#
# To evaluate the network  feed one character at a time, use the outputs of the network as a probability distribution for the next character, and repeat. To start generation  pass a priming string to start building up the hidden state, from which you then generate one character at a time.
#
# In the below function let us assign the default primary string as 'A' and to choose a class with a probability output use the [muiltinomial distribution](https://pytorch.org/docs/master/generated/torch.multinomial.html)

# %%
def evaluate(prime_str='A', predict_len=100, temperature=0.8):
    hidden = rnn.init_hidden()
    prime_input = char_tensor(prime_str)
    predicted = prime_str

    # Use priming string to "build up" hidden state
    for p in range(len(prime_str) - 1):
        _, hidden = rnn(prime_input[p], hidden)
    inp = prime_input[-1]

    for p in range(predict_len):
        output, hidden = rnn(inp, hidden)

        # Applying Softmax & Sample from the network as a multinomial distribution
        output_dist = output.data.view(-1).div(temperature).exp()
        top_i = torch.multinomial(output_dist, 1)[0]

        # Add predicted character to string and use as next input
        predicted_char = all_characters[top_i]
        predicted += predicted_char
        inp = char_tensor(predicted_char)

    return predicted

# %% [markdown]
# ### 4. Training the Model
#
# To keep track of how long training takes, let us add a time_since(timestamp) function which returns a human readable string:

# %%
# Function to print amount of time passed
def time_since(since):
    s = time.time() - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

# %% [markdown]
# #### The main training function

# %%
def train(inp, target):
    # Initialize the hidden representation, gradient, loss to zeros
    hidden = rnn.init_hidden()
    rnn.zero_grad()
    loss = 0

    for c in range(chunk_len):
        output, hidden = rnn(inp[c], hidden)
        '''unsqueeze() is used to add dimension to the tensor'''
        loss += criterion(output, target[c].unsqueeze(dim=0))
    # Back propagation
    loss.backward()
    rnn_optimizer.step()

    return loss.item() / chunk_len

# %% [markdown]
# Then define the training parameters, instantiate the model, and start training. In the below cell  try to print the chunk, loss and time taken for every 50th iteration and for every 20th iteration  try to plot the loss vs epochs(iterations).

# %%
n_epochs = 2000 # Number of epochs
print_every = 50
plot_every = 20
hidden_size = 100
n_layers = 1
lr = 0.005

# The input_size & output_size are the total number of n_characters
rnn = RNN(n_characters, hidden_size, n_characters, n_layers) # The rnn variable consists of the return values from the RNN model

# Optimize
rnn_optimizer = torch.optim.Adam(rnn.parameters(), lr=lr)

# Loss function
criterion = nn.CrossEntropyLoss()

start = time.time()
all_losses = []
loss_avg = 0

for epoch in range(1, n_epochs + 1):
    loss = train(*random_training_set())
    loss_avg += loss

    if epoch % print_every == 0:
        print('[%s (%d %d%%) %.4f]' % (time_since(start), epoch, epoch / n_epochs * 100, loss))
        print(evaluate('Wh', 100), '\n')

    if epoch % plot_every == 0:
        all_losses.append(loss_avg / plot_every)
        loss_avg = 0
# Out:
#  9s (50 2%) 2.5019]
# Whef ar meut the m ucek thr orme kis thi ay fule thof me, me, wemacut te;
# NLmy nort ou Lou ser, wurue
#
#  17s (100 5%) 2.1924]
# Whis wichicht the yourle sont fe:
# I you o tol.
#
# Rot Laves is hese whenstend uone
#
# KIS aill Vord ard ho
#
#  25s (150 7%) 2.2747]
# Whe pradse han, inbalods thou, sseming thus you with, you mereen whereane westh, thetseing, mastnanten
#
#  34s (200 10%) 2.1519]
# Whee; I pondine, ranon I gand kither thentend; to shan
# ffire, the in beard to be breseld gonds:
# And re
#
#  42s (250 12%) 1.9319]
# Whlinsonfirer evetcomrer the full hel
# Mower and
# As bliel inp hem and afe to and beake; as theel the ki
#
#  50s (300 15%) 2.0174]
# Whicoush thou so vady rever ton haged or my I here more the leparde!
# Sile be in socion lens thand is w
#
#  58s (350 17%) 1.9731]
# Wher.
#
# KING RICCEL:
# And untan, your mest de swearln sown washs to there sep
# Whould aut of Rones sencac
#
#  6s (400 20%) 2.0493]
# Whis for a tome thig, you fauldank
#
# Thow Kead and wan.
#
# MEETENIO:
# I knowt a will all whou have the me
#
#  14s (450 22%) 1.9328]
# Whant hund have eure with Eadand Lord:
# As the so,
# Ther he swainks, alls, thy heas then.
#
# MENENER:
# Sid.
#
#  23s (500 25%) 1.9445]
# Whe.
#
# VANIUCIUS:
# His thy sill the here I sence, shall to thirn have preou plorent the wis san wart not
#
#  30s (550 27%) 2.0244]
# What mand the shame your so me;
# And san thee spase see untiumer's dist slaine hat her cencake shee
# I p
#
#  38s (600 30%) 1.6932]
# Where whecking as ar the reed for I know here in in in the, and deard and me this wife it depweeth poa
#
#  47s (650 32%) 2.1067]
# Whow on
# There feetings
# And it deark your stard my with ant deat?
# And dees he not mise:
# Whall come the
#
#  57s (700 35%) 1.8712]
# What I selver these.
#
# DUKE IGHE:
# No, the courld leeths that we curnownce's a degelad slear!
# You that w
#
#  5s (750 37%) 1.9967]
# Which to odrusond
# The hee'l to be my my trage and shall be bet for. I shy to thy upents a hes hemand s
#
#  13s (800 40%) 2.0375]
# Which: at no throure have,
# Foo sleve, with such the hain--ward!
#
# AUTENTIO:
# Jifful be'd theriing of hav
#
#  21s (850 42%) 2.0263]
# Whift dis the joysed the brightermal be drage.
#
# LUCENTER:
# Not.
#
# OUNGRANE:
# Dath the have, in hard, a be
#
#  29s (900 45%) 1.9781]
# Where not this not all the lies as wo, I that with's not sone they to hath the repton these age, fay,
#
#  38s (950 47%) 1.7174]
# What Cace.
# First a borter
# The may all he mast the non a he not one, be pitce, and then shall to
# him.
#
#
#
#  45s (1000 50%) 1.8455]
# Where;
# And you over such reads, your I not the fain and shat it you, I word light, and face, I with fa
#
#  53s (1050 52%) 1.8204]
# What, stall is ol that Sirion.
# But plates fury sor then, we in this the sodon your and,
# But will lovic
#
#  2s (1100 55%) 1.8793]
# Whe chands,
# Be blood there your piting: thing reighting so there her'd forcelf;
# amother,
# Lord seess fo
#
#  9s (1150 57%) 2.0137]
# Whe deast of what the with tell.
#
# COMINIUS:
# Has way it not hinks, and was he soodser tas well beady.
#
#
#
#  18s (1200 60%) 1.7386]
# What I pright than daspuen. That sorrow
# And my lad thus and one,
# And of stake the am come ood not deve
#
#  26s (1250 62%) 1.9559]
# Why to my, theirs dot one again.
#
# RIICHARD III:
# Wherbreng brady choppoot by the canmel of migh to od t
#
#  34s (1300 65%) 1.5668]
# Whour I do go, hers.
#
# By gentle. Bast I will with there say I agauleme:
# To my so me stand I all beite
#
#  43s (1350 67%) 1.8016]
# When inder I lever, and to know;
# I montly be havere
# Scaling we so not what of the have frave a comlo.
#
#
#  50s (1400 70%) 1.8358]
# What with cown!
#
# MENENIUS:
# If vere you than a now wears,
# But neen nex and fere you she caill the lords
#
#  59s (1450 72%) 1.7884]
# What for sided stated seej love thy sone good the ere is life's for wecond,
# And the sust not was I hav
#
#  7s (1500 75%) 1.7350]
# What pow this the sure a deid the comuretiand
# To she chil-O command my not the of may remsterbivistor
#
#  15s (1550 77%) 1.9554]
# Whould le fies not but basess fear them.
#
# PRONENENENUS:
# Not the cring yet;
# A pees it for shall Tongus
#
#  23s (1600 80%) 1.7674]
# Why heriam'd bean a kesers
# For slase me thou aglanit,
# Astersy,
# Yo, all father, at she cair may hear ha
#
#  32s (1650 82%) 1.8197]
# Whan the nother'm and the ware, wither, it the had sonle
# The death amad rany bood hards not man shall
#
#  39s (1700 85%) 2.1098]
# What earth sollore a play of besto'd out, by fo.
#
# LOUCESTER:
# I purp the man you no comman adve the kis
#
#  48s (1750 87%) 1.9433]
# Whom mum: but your you they more the akging pent with as.
#
# MENENIUS:
# Sicking thals as ham and not hera
#
#  56s (1800 90%) 1.9124]
# What goften in sure mught like for my call up
# This dave said my belien smench to to love maing-porion
#
#  4s (1850 92%) 1.3684]
# Why lithars like very sold us a recond to the mose such grother
# And piend, seing. The ward mustle mone
#
#  12s (1900 95%) 1.6556]
# When is in here a bear How ligh.
# A blay, or one we he love a hearth a his is the boase did reveroush a
#
#  20s (1950 97%) 1.6670]
# Whobles,
# Was mely was so comester,
# To to but some have solloh thee hall thou thou that thou king, thee
#
#  28s (2000 100%) 1.7064]
# Where saint.
#
# Shomand onnemsed.
#
# DER ETIO:
# So bellow strands I have corewerusure,
# Comeat some it him?

# %% [markdown]
# #### Plotting the Training Losses
#
# Plotting the historical loss from all_losses shows the network learning:

# %%
plt.figure()
plt.plot(all_losses)
plt.xlabel("epoch")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ### 5. Adapting or Tuning for Text Generation
#
# In the evaluate function above, every time a prediction is made, the outputs are divided by the "temperature" argument passed. Using a higher number makes all actions more equally likely, and thus gives us "more random" outputs. Using a lower value (less than 1) makes high probabilities contribute more. By turning the temperature towards zero you are choosing only the most likely outputs.

# %% [markdown]
# Let us see the effects of this by adjusting the temperature argument:

# %%
print(evaluate('u', 200, temperature=0.8))
# Out:
# uch's every but the she beging
# my seemed weing the strake in in the done:
# I so many sarer me should stiring buster, and your virton comet.
# First hust well you kings that sure, set to thee mows and see

# %% [markdown]
# Lower temperatures are less varied, choosing only the more probable outputs:

# %%
print(evaluate('Th', 200, temperature=0.2))
# Out:
# There sone to shall the so sever the so the so should so strands
# I seem and the strand and and as so the seem and the say and the strong and so me and the see.
#
# CORIOLANUS:
# I she strance and the so many

# %% [markdown]
# Higher temperatures more varied, choosing less probable outputs:

# %%
print(evaluate('how', 200, temperature=1.4))
# Out:
# how ow's is apoll, ox shols
# Of yis debusehemow sever-shom Eadst hows.
# My never.?
#
# AMM0IO: I'll;
# miny mean'd.
#
# BAPHIBOPXTIS:
# Om I say, bo best bew'd twen: so preo'rs
# Here'd withind tiveved who! requei'w'k

# %% [markdown]
# ### Ungraded Exercise 1:
#
# Change the number of epochs to 1000. Calculate the time taken and loss:

# %%
# YOUR CODE HERE
n_epochs = 1000
print_every = 50
plot_every = 20
hidden_size = 100
n_layers = 1
lr = 0.005

# Instantiate model, optimizer, and loss criterion
rnn = RNN(n_characters, hidden_size, n_characters, n_layers)
rnn_optimizer = torch.optim.Adam(rnn.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

start = time.time()
all_losses = []
loss_avg = 0

# Training loop over 1000 epochs
for epoch in range(1, n_epochs + 1):
    loss = train(*random_training_set())
    loss_avg += loss

    if epoch % print_every == 0:
        print('[%s (%d %d%%) %.4f]' % (time_since(start), epoch, epoch / n_epochs * 100, loss))
        print(evaluate('Wh', 100), '\n')

    if epoch % plot_every == 0:
        all_losses.append(loss_avg / plot_every)
        loss_avg = 0

# Output final time taken and average loss
total_time = time_since(start)
final_loss = all_losses[-1] if all_losses else loss

print(f"\nTraining Complete!")
print(f"Total Time Taken: {total_time}")
print(f"Final Loss: {final_loss:.4f}")
# Out:
#  8s (50 5%) 2.6533]
# Whe sthind capand ant net cinge limat hinghis ow poof llye,
# And
# CId hins mint sin chard wins fo; inaan
#
#  16s (100 10%) 2.4138]
# Why the thand fathis and sof youw you tont a duchy hour ther?
# Whe tly thalell.
#
# NELUIMNG hy and you me
#
#  24s (150 15%) 2.3338]
# Whot hou is
#
# Whe fos the thin of ay bo all YLENO:
# In leadle,
# Bus thed the the fowrith a loder thimser
#
#  33s (200 20%) 2.1834]
# Whis RICIZO:
# some my thitnis a hearw highere hies of of withan the?
# or ing of forter'd the be ot I bus
#
#  41s (250 25%) 2.0583]
# Whan dour.
# A mornou but purmpreast, in const and weole at so bus ables,
# So hangon, bom, shave sinter o
#
#  49s (300 30%) 2.2772]
# Wht your trend, the thon not hanters nere corkeonce.
#
# The go you will and to your my whiy of you deam
#
#  58s (350 35%) 1.9945]
# Wh'd by my sils to peeng bow-beood befnound befores
# What to therefouns of the hefe thy then thow boy w
#
#  6s (400 40%) 1.9432]
# Whent.
#
# PROLIUS:
# With seepe the pit of is of pis to end thou hancous the his my me nother to to to lob
#
#  14s (450 45%) 2.0403]
# Whad you werely mesang dige in begelwonk hade bust all shaf.
#
# BARDY APICES: my
#  wise ham your a descur
#
#  22s (500 50%) 2.0878]
# Whirmincher,
# On you loved but of the sark'd baje.
#
# QUKE VIO:
# Iy then with cear trumonty!
# Nordlact and
#
#  30s (550 55%) 1.9483]
# Whire underisuch I'll vathing,
# Wich chanserer:
# To we hae ewince,
# But be sworre: for they and croust a
#
#  39s (600 60%) 1.9986]
# Whord, he to she say.
#
# SIO:
# For book,
# Whaty gatirion, to hase the fall,
# Anl fright a hid ought my grag
#
#  47s (650 65%) 1.9183]
# Why the fay yough; a so deed a for them,
# With the ruckneas'd to deepefever,
# Ahd I hoselser'd tim a dfu
#
#  55s (700 70%) 1.8773]
# Whall; it in day;
# Buch spore love thy you ngle adrow juplaseevel
# What crad you all ing have thou ham o
#
#  3s (750 75%) 1.9217]
# Wht, my dentill,
# Night a him not is the muckle ler our sild,
# And let our thear, your placers,
# in to so
#
#  11s (800 80%) 2.0164]
# Wherer.
#
# RPERTIO:
# It to we a prancel, lating of be to to wo be not beate.
# I will wills it a that words
#
#  19s (850 85%) 1.7570]
# Whath.
#
# WARINCALUS:
# Go stience and such no' be and they sould sinten
# So say that his the cuts so greep
#
#  27s (900 90%) 1.8753]
# Whly. Threalt bland,
# The ovelf, he distage the redangue,
# Thou hearted, coutted me the up mes.
#
# PAULET:
#
#  36s (950 95%) 1.9282]
# Wher.
#
# JULIA:
# That a vill trom the parrity, be spow, them gome, I well he if you, to as To patizen,
# Bu
#
#  44s (1000 100%) 1.8636]
# Whath how that here
# you and, your for a bother your begrear, to ring and the shall you resont shall
# We
#
#
# Training Complete!
# Total Time Taken: 2m 44s
# Final Loss: 1.8901

# %% [markdown]
# ### Acknowledgement
#
# https://blog.owulveryck.info/2017/10/29/about-recurrent-neural-network-shakespeare-and-go.html

# %% [markdown]
# ### Please answer the questions below to complete the experiment:

# %%
#@title State True or False: When we turn the temperature towards zero, it means that we are choosing only the most similar outputs. { run: "auto", form-width: "500px", display-mode: "form" }
Answer = "TRUE" #@param ["","TRUE", "FALSE"]

# %%
#@title How was the experiment? { run: "auto", form-width: "500px", display-mode: "form" }
Complexity = "Good and Challenging for me" #@param ["","Too Simple, I am wasting time", "Good, But Not Challenging for me", "Good and Challenging for me", "Was Tough, but I did it", "Too Difficult for me"]

# %%
#@title If it was too easy, what more would you have liked to be added? If it was very difficult, what would you have liked to have been removed? { run: "auto", display-mode: "form" }
Additional = "NA" #@param {type:"string"}

# %%
#@title Can you identify the concepts from the lecture which this experiment covered? { run: "auto", vertical-output: true, display-mode: "form" }
Concepts = "Yes" #@param ["","Yes", "No"]

# %%
#@title  Experiment walkthrough video? { run: "auto", vertical-output: true, display-mode: "form" }
Walkthrough = "Very Useful" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title  Text and image description/explanation and code comments within the experiment: { run: "auto", vertical-output: true, display-mode: "form" }
Comments = "Very Useful" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title Mentor Support: { run: "auto", vertical-output: true, display-mode: "form" }
Mentor_support = "Very Useful" #@param ["","Very Useful", "Somewhat Useful", "Not Useful", "Didn't use"]

# %%
#@title Run this cell to submit your notebook for grading { vertical-output: true }
try:
  if submission_id:
      return_id = submit_notebook()
      if return_id : submission_id = return_id
  else:
      print("Please complete the setup first.")
except NameError:
  print ("Please complete the setup first.")
# Out:
# Your submission is successful.
# Ref Id: 5038
# Date of submission:  12 Sep 2026
# Time of submission:  16:11:51
# View your submissions: https://learn-iiith.talentsprint.com/notebook_submissions
